# %% [markdown]
# <a href="https://colab.research.google.com/github/Manc0lat3/ET_JoseValdivia_PGY1121_005_V/blob/main/JoseValdivia_PGY1121_005_V.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime

precio1 = {
    'A': 3800,
    'B': 3000,
    'C': 2800,
    'D': 3500
}

def formato(rut):
  rutformato = rut[:-1] + '-' + rut[-1]
  rutformato = rutformato[::-1]
  return rutformato[::-1]

def listado1():
  print('')
  print('== Listado de Compradores ==')
  for rut, nombre, departamento in compradores:
      formato_rut = formato(rut)
      print(f'RUN: {formato_rut} - Nombre: {nombre} - Departamento: {departamento}')

depa = [['' for _ in range(4)] for _ in range(10)]

compradores = []

def comprar():
  print('')
  print('\tComprar Departamento')
  pisos = int(input('Ingrese el número de pisos (1-10): '))
  letras = input('Ingrese el letras de departamento (A, B, C, D): ').upper()

  if 1 <= pisos <= 10 and letras in precio1.keys():
      departamento = depa[pisos - 1][ord(letras) - ord('A')]
      if departamento == '':
          rut=input('Ingresa su rut (Sin puntos ni guion): ')
          nombre = input('Ingrese el nombre completo del comprador: ')
          seguro=input('¿Estas seguro de comprar el departamento? (S/N)').upper()
          if seguro=='S':
            departamento = f'{letras}{pisos}'
            depa[pisos - 1][ord(letras) - ord('A')] = departamento
            compradores.append((rut, nombre, departamento))
            print('¡Departamento comprado exitosamente!')
          elif seguro=='N':
            print('Compra anulada con exito.')
          else:
            print('ERROR: Opcion incorrecta, vuelva a realizar la compra.')
            return()
      else:
          print('El departamento seleccionado no está disponible.')
  else:
      print('Opción inválida.')

def mostrar():
  print('')
  print('Departamentos Disponibles')
  print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
  print('| pisos | A   | B   | C   | D   |')
  print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
  for i in range(10):
      pisos = i + 1
      row = f'|   {pisos}  |'
      for j in range(4):
          letras = chr(ord('A') + j)
          departamento = depa[i][j]
          estado = 'X' if departamento != '' else ' '
          row += f'  {estado}  |'
      print(row)
  print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')

def listado():
  print('')
  print('\tCompradores')
  for rut, nombre, departamento in compradores:
      print(f'RUN: {rut} - Nombre: {nombre} - Departamento: {departamento}')

def ganancias():
  print('')
  print('\tTotal de Ganancias')
  print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
  print('| letras | Cantidad | Total     |')
  print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
  total = 0
  for letras, precio in precio1.items():
      cantidad = sum([1 for pisos in depa for departamento in pisos if departamento.startswith(letras)])
      subtotal = cantidad * precio
      total += subtotal
      print(f'|  {letras}  |   {cantidad}    | {subtotal:9.2f} UF |')
  print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
  print(f"Total    |   {sum([sum([1 for departamento in pisos if departamento != '']) for pisos in depa])}    | {total:9.2f} UF |")

def princi():
  print('Bienvenido al programa de inmobiliaria CASA FELIZ')
def menu1():
  while True:
      print('')


      print('== Sistema de Control de Venta de Departamentos ==')
      print('1. Comprar Departamento')
      print('2. Mostrar Departamentos Disponibles')
      print('3. Ver Listado de Compradores')
      print('4. Mostrar Ganancias Totales')
      print('5. Salir')
      print('')
      menu = (input('Ingrese una opción (1-5): '))

      if menu == '1':
          comprar()
      elif menu == '2':
          mostrar()
      elif menu == '3':
          listado1()
      elif menu == '4':
          ganancias()
      elif menu == '5':
        now = datetime.datetime.now()
        print('¡Gracias por utilizar el sistema de control de venta de departamentos de Casa Feliz, vuelva pronto!')
        for run, nombre, departamento in compradores:
          print(f'¡Muchas gracias por su compra {nombre}!')
        print(f'Fecha: {now.strftime("%d/%m/%Y")}')
        break
      else:
          print('Opción inválida.')




if __name__=='__main__':
  princi()
  menu1()
